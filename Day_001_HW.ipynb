# %% [markdown]
# # 作業壹
# Q1. 你選的這組資料為何重要
#
# Q2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#
# Q3. 蒐集而來的資料型態為何
#
# Q4. 這組資料想解決的問題如何評估
#
# ### Homework 1 - Answer
# 選用[Human Protein Atlas Image Classification](https://www.kaggle.com/c/human-protein-atlas-image-classification)
#
# A1. 可視化細胞中蛋白質的蛋白質圖像用於生物醫療科學研究，瞭解這些細胞可促成醫療相關領域的突破。
#
# A2. 由[The Human Protein Atlas team](https://www.proteinatlas.org/)提供，
# 使用共軛焦顯微鏡拍攝蛋白質圖像。
#
# A3. 都是透過smart-microscopy system拍攝的高傳輸量圖像
#
# A4. 由於高通量顯微鏡的進步，這些圖像的生成速度遠遠超過人工評估的速度。因此，對於自動化生物醫學圖像分析以加速對人類細胞和疾病的理解，需要比以往更大的需求。
#
# # 作業貳
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
#
# Q1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#
# Q2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#
# Q3. 蒐集而來的資料型態為何
#
# Q4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#
# ### Homework 2 - Answer
#
# A1. 什麼客群?什麼時段?什麼地點?
# 首先瞭解到什麼人會搭車 e.g.旅客、上班族、趕時間的人
# 是因為旅遊、出差、急事...etc
# 根據蒐集的資料瞭解什麼客群是增加業績的關鍵。
#
# 一整天中什麼時段的載客率高?一整月有幾天的載客率特別高嗎?為什麼?
# 一年中旅遊淡旺季是什麼月份?淡旺季的載客率又分別是多少?
# 最後是載客量大的地點，扣除等人與油錢等成本後，可以產生高收益的點。
# e.g. 機場、捷運站、轉運站、商辦大樓、百貨公司、科技園區、觀光景點...etc
#
# A2. 透過App叫車的乘客，就可蒐集到時段、地點，並透過定位系統，
# 知道叫車地點是什麼樣的環境，並從起終點判斷對方是什麼樣的客群。
# 來電叫車的乘客，就在電話中詢問相關資訊並記錄。
# 針對性別、年齡、是否為本地人，可能要司機記錄、回報。
#
# A3. 類別資料、等距資料，較無影音等非結構化資料。
#
# A4. 資料建成模型並以視覺化呈現，比較各週、月份
#
# # 作業叁
# ### Homework 3 - Answer
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, yp):
    
    MSE = sum((y - yp) ** 2) / len(y)
    return MSE

def mean_absolute_error(y, yp):
    
    MAE = sum(abs(y - yp)) / len(y)
    return MAE

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 247.055
# The Mean absolute error is 13.116
